# %% [markdown]
# # Jupyter notebook for DHKO 2024, Trondheim
#
# Innføring i hvordan bruke Nasjonalbibliotekets DH-lab. Notebooken har referanser til boken [Python4abm](https://mich123prem.github.io/python4abm/intro.html#) her og der.
#
# https://www.nb.no/dh-lab/
#
# Lars G Bagøien Johnsen

# %% [markdown]
# ## Start
#
# Importer dhlab og pandas

# %%
import dhlab as dh
import pandas as pd

# noe kode er ikke ferdig bygd inn
import dhlab.api.dhlab_api as api

# %% [markdown]
# ## Korpus av tekster
#
# Alt starter med en mengde tekster.

# %%
corpus_definition = dh.Corpus(doctype="digibok", subject="mat", from_year=1960, to_year=2010, lang='nob', limit=500)

# %% [markdown]
# Alle korpus tilhører klasse for NB. Vi skal hente ut selve datarammen fra klassen (se [Python4abm - datarammer](https://mich123prem.github.io/python4abm/kapittel8.html#dataanalyse-med-pandas)) og jobbe videre med den.

# %%
corpus_pandas = corpus_definition.frame

# %% [markdown]
# ## Inspiser korpus
#
# Bruk pandas kommandoer for å finne bøker, eller velge delmengder av bøker

# %%
# Få en liste over kolonnene i korpusobjektene
corpus_pandas.columns
# Out:
# Index(['dhlabid', 'urn', 'title', 'authors', 'oaiid', 'sesamid', 'isbn10',
#        'city', 'timestamp', 'year', 'publisher', 'langs', 'subjects', 'ddc',
#        'genres', 'literaryform', 'doctype', 'ocr_creator', 'ocr_timestamp'],
#       dtype='object')

# %% [markdown]
# Begrens korpuset til å vise de mest essensielle dataene. Gjør listen så liten du vil, men ta med dhlabid og urn

# %%
corpus_pandas[['dhlabid', 'urn', 'title', 'authors','city', 'year', 'publisher', 'langs', 'subjects', 'ddc',
       'genres', 'literaryform', 'doctype']].head(5)
# Out:
#      dhlabid                                  urn  \
# 0  100534356  URN:NBN:no-nb_digibok_2011021803013
# 1  100447477  URN:NBN:no-nb_digibok_2009020904012
# 2  100479292  URN:NBN:no-nb_digibok_2016011508026
# 3  100139482  URN:NBN:no-nb_digibok_2013020808105
# 4  100466058  URN:NBN:no-nb_digibok_2008010800028
#
#                                                title  \
# 0        Culinaria Frankrike : franske spesialiteter
# 1  Matvarekvalitet og sikkerhet i planteproduksjonen
# 2                          Mu mátematihkka : Mánnu 4
# 3  Radioaktivitet , miljøgifter og bruk av kostho...
# 4                                        Innlandsmat
#
#                                              authors       city  year  \
# 0  Myhr , Eirik / Dominé , André / Beer , Günter ...             2008
# 1                                                          Oslo  1997
# 2                                                          Oslo  1984
# 3               Storstad , Oddveig / Heggem , Reidun  Trondheim  1999
# 4  Hagen , Helge / Klingwall , Gunnar / Syverinse...             1993
#
#                                            publisher            langs  \
# 0                                           Spektrum        nob / ger
# 1  Norges forskningsråd, Området for bioproduksjo...              nob
# 2                                        Tanum-Norli  sme / nob / swe
# 3                          Senter for bygdeforskning              nob
# 4                Kokkenes mesterlaug Hedmark-Oppland              nob
#
#                                             subjects         ddc genres  \
# 0  kokebøker / frankrike / fransk / mat / oppskri...    641.5944
# 1  Mat / Sikkerhet / Ernæring / Næringsmidler / m...
# 2                                   mat / oahpogirji         510
# 3  Nutrition / Education / Food contamination, ra...
# 4           kokebøker / norsk / mat / mattradisjoner  641.594824
#
#     literaryform  doctype
# 0  Faglitteratur  digibok
# 1  Uklassifisert  digibok
# 2  Faglitteratur  digibok
# 3  Faglitteratur  digibok
# 4  Faglitteratur  digibok

# %% [markdown]
# Vi legger korpus inn under navnet corpus - og lager en kopi av den opprinnelige rammen

# %%
corpus = corpus_pandas[['dhlabid', 'urn', 'title', 'authors','city', 'year', 'publisher', 'langs', 'subjects', 'ddc',
       'genres', 'literaryform', 'doctype']].copy()

# %%
corpus.head(5)
# Out:
#      dhlabid                                  urn  \
# 0  100534356  URN:NBN:no-nb_digibok_2011021803013
# 1  100447477  URN:NBN:no-nb_digibok_2009020904012
# 2  100479292  URN:NBN:no-nb_digibok_2016011508026
# 3  100139482  URN:NBN:no-nb_digibok_2013020808105
# 4  100466058  URN:NBN:no-nb_digibok_2008010800028
#
#                                                title  \
# 0        Culinaria Frankrike : franske spesialiteter
# 1  Matvarekvalitet og sikkerhet i planteproduksjonen
# 2                          Mu mátematihkka : Mánnu 4
# 3  Radioaktivitet , miljøgifter og bruk av kostho...
# 4                                        Innlandsmat
#
#                                              authors       city  year  \
# 0  Myhr , Eirik / Dominé , André / Beer , Günter ...             2008
# 1                                                          Oslo  1997
# 2                                                          Oslo  1984
# 3               Storstad , Oddveig / Heggem , Reidun  Trondheim  1999
# 4  Hagen , Helge / Klingwall , Gunnar / Syverinse...             1993
#
#                                            publisher            langs  \
# 0                                           Spektrum        nob / ger
# 1  Norges forskningsråd, Området for bioproduksjo...              nob
# 2                                        Tanum-Norli  sme / nob / swe
# 3                          Senter for bygdeforskning              nob
# 4                Kokkenes mesterlaug Hedmark-Oppland              nob
#
#                                             subjects         ddc genres  \
# 0  kokebøker / frankrike / fransk / mat / oppskri...    641.5944
# 1  Mat / Sikkerhet / Ernæring / Næringsmidler / m...
# 2                                   mat / oahpogirji         510
# 3  Nutrition / Education / Food contamination, ra...
# 4           kokebøker / norsk / mat / mattradisjoner  641.594824
#
#     literaryform  doctype
# 0  Faglitteratur  digibok
# 1  Uklassifisert  digibok
# 2  Faglitteratur  digibok
# 3  Faglitteratur  digibok
# 4  Faglitteratur  digibok

# %% [markdown]
# Vi kan sikre oss entydig verdi av språk med hjelp av pandas filtrering
#
# Les om hvordan lage delmenger med pandas i [Python4abm - filtrering](https://mich123prem.github.io/python4abm/kapittel8.html#utdrag-av-radene-filtrering)

# %%
corpus['antall_språk'] = corpus['langs'].apply(lambda x: len(x.split('/')))

# %%
corpus[corpus['antall_språk'] == 1].head(5)
# Out:
#      dhlabid                                  urn  \
# 1  100447477  URN:NBN:no-nb_digibok_2009020904012
# 3  100139482  URN:NBN:no-nb_digibok_2013020808105
# 4  100466058  URN:NBN:no-nb_digibok_2008010800028
# 6  100106103  URN:NBN:no-nb_digibok_2012082205069
# 8  100081620  URN:NBN:no-nb_digibok_2012061905116
#
#                                                title  \
# 1  Matvarekvalitet og sikkerhet i planteproduksjonen
# 3  Radioaktivitet , miljøgifter og bruk av kostho...
# 4                                        Innlandsmat
# 6                      Tradisjonsbakst fra Helgeland
# 8  Jorda rundt på to dager : mikrobielle turister...
#
#                                              authors       city  year  \
# 1                                                          Oslo  1997
# 3               Storstad , Oddveig / Heggem , Reidun  Trondheim  1999
# 4  Hagen , Helge / Klingwall , Gunnar / Syverinse...             1993
# 6                                  Kaspersen , Ardis             2004
# 8  Skjerve , Eystein / Wasteson , Emilie Kildegaa...       Oslo  1999
#
#                                            publisher langs  \
# 1  Norges forskningsråd, Området for bioproduksjo...   nob
# 3                          Senter for bygdeforskning   nob
# 4                Kokkenes mesterlaug Hedmark-Oppland   nob
# 6                                  [Ardis Kaspersen]   nob
# 8                                     Landbruksforl.   nob
#
#                                             subjects          ddc genres  \
# 1  Mat / Sikkerhet / Ernæring / Næringsmidler / m...
# 3  Nutrition / Education / Food contamination, ra...
# 4           kokebøker / norsk / mat / mattradisjoner   641.594824
# 6  lokalhistorie / mattradisjoner / baking / nord...  641.5948441
# 8  Biotechnology / Environmental protection / Ant...       616.92
#
#     literaryform  doctype  antall_språk
# 1  Uklassifisert  digibok             1
# 3  Faglitteratur  digibok             1
# 4  Faglitteratur  digibok             1
# 6  Faglitteratur  digibok             1
# 8  Faglitteratur  digibok             1

# %% [markdown]
# ## Hente data
#
# Når vi har korpuset kan vi hente ut data for inspeksjon og analyse.
#
# Det er to typer konkordanser, en med fulltekstsyntaks (trunkering nærhetskrav), og en som matcher nøyaktig.

# %%
conc = dh.Concordance(corpus=corpus, query="NEAR(salt pepper, 10)")

# %%
conc.size
# Out:
# 500

# %%
conc.show(10)
# Out:
# <style type="text/css">
# </style>
# <table id="T_e657c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e657c_level0_col0" class="col_heading level0 col0" >link</th>
#       <th id="T_e657c_level0_col1" class="col_heading level0 col1" >concordance</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e657c_level0_row0" class="row_heading level0 row0" >128</th>
#       <td id="T_e657c_row0_col0" class="data row0 col0" ><a target='_blank' href = 'https://urn.nb.no/URN:NBN:no-nb_digibok_2017013148013'>URN:NBN:no-nb_digibok_2017013148013</a></td>
#       <td id="T_e657c_row0_col1" class="data row0 col1" >Til grill : V2 ss olje , <b>salt</b> , <b>pepper</b></td>
#     </tr>
#     <tr>
#       <th id="T_e657c_level0_row1" class="row_heading level0 row1" >83</th>
#       <td id="T_e657c_row1_col0" class="data row1 col0" ><a target='_blank' href = 'https://urn.nb.no/URN:NBN:no-nb_digibok_2014012338017'>URN:NBN:no-nb_digibok_2014012338017</a></td>
#       <td id="T_e657c_row1_col1" class="data row1 col1" >... Smak til med <b>salt</b> og <b>pepper</b> Det er også godt med finhakkete friske urter i denne sausen.Ta det du har-... </td>
#     </tr>
#     <tr>
#       <th id="T_e657c_level0_row2" class="row_heading level0 row2" >22</th>
#       <td id="T_e657c_row2_col0" class="data row2 col0" ><a target='_blank' href = 'https://urn.nb.no/URN:NBN:no-nb_digibok_2011022803045'>URN:NBN:no-nb_digibok_2011022803045</a></td>
#       <td id="T_e657c_row2_col1" class="data row2 col1" >... Krydre det med <b>salt</b> og <b>pepper</b> . Ha smør i en stekepanne</td>
#     </tr>
#     <tr>
#       <th id="T_e657c_level0_row3" class="row_heading level0 row3" >203</th>
#       <td id="T_e657c_row3_col0" class="data row3 col0" ><a target='_blank' href = 'https://urn.nb.no/URN:NBN:no-nb_digibok_2008090804071'>URN:NBN:no-nb_digibok_2008090804071</a></td>
#       <td id="T_e657c_row3_col1" class="data row3 col1" >... Smakes så til med <b>salt</b> og <b>pepper</b> .</td>
#     </tr>
#     <tr>
#       <th id="T_e657c_level0_row4" class="row_heading level0 row4" >86</th>
#       <td id="T_e657c_row4_col0" class="data row4 col0" ><a target='_blank' href = 'https://urn.nb.no/URN:NBN:no-nb_digibok_2016072048078'>URN:NBN:no-nb_digibok_2016072048078</a></td>
#       <td id="T_e657c_row4_col1" class="data row4 col1" >... Smak til med fruktose , <b>salt</b> og <b>pepper</b> .</td>
#     </tr>
#     <tr>
#       <th id="T_e657c_level0_row5" class="row_heading level0 row5" >431</th>
#       <td id="T_e657c_row5_col0" class="data row5 col0" ><a target='_blank' href = 'https://urn.nb.no/URN:NBN:no-nb_digibok_2015052648004'>URN:NBN:no-nb_digibok_2015052648004</a></td>
#       <td id="T_e657c_row5_col1" class="data row5 col1" >... Jo lengre sausen koker , jo bedre blir den.Tilsett fløte og smak til med eddik , <b>salt</b> og <b>pepper</b> .... </td>
#     </tr>
#     <tr>
#       <th id="T_e657c_level0_row6" class="row_heading level0 row6" >341</th>
#       <td id="T_e657c_row6_col0" class="data row6 col0" ><a target='_blank' href = 'https://urn.nb.no/URN:NBN:no-nb_digibok_2011022803045'>URN:NBN:no-nb_digibok_2011022803045</a></td>
#       <td id="T_e657c_row6_col1" class="data row6 col1" >... , kremfløte , <b>salt</b> , <b>pepper</b> og sukker . Kok grønnsakene møre i vann uten <b>salt</b> , slå av vannet... </td>
#     </tr>
#     <tr>
#       <th id="T_e657c_level0_row7" class="row_heading level0 row7" >289</th>
#       <td id="T_e657c_row7_col0" class="data row7 col0" ><a target='_blank' href = 'https://urn.nb.no/URN:NBN:no-nb_digibok_2017013148013'>URN:NBN:no-nb_digibok_2017013148013</a></td>
#       <td id="T_e657c_row7_col1" class="data row7 col1" >4 hg kalv- eller svinelever til griljering : mel , <b>salt</b> , <b>pepper</b> til steking : smør eller olje</td>
#     </tr>
#     <tr>
#       <th id="T_e657c_level0_row8" class="row_heading level0 row8" >496</th>
#       <td id="T_e657c_row8_col0" class="data row8 col0" ><a target='_blank' href = 'https://urn.nb.no/URN:NBN:no-nb_digibok_2016021507576'>URN:NBN:no-nb_digibok_2016021507576</a></td>
#       <td id="T_e657c_row8_col1" class="data row8 col1" >... Tilsett <b>salt</b> og nymalt svart <b>pepper</b> etter smak .</td>
#     </tr>
#     <tr>
#       <th id="T_e657c_level0_row9" class="row_heading level0 row9" >39</th>
#       <td id="T_e657c_row9_col0" class="data row9 col0" ><a target='_blank' href = 'https://urn.nb.no/URN:NBN:no-nb_digibok_2014020348054'>URN:NBN:no-nb_digibok_2014020348054</a></td>
#       <td id="T_e657c_row9_col1" class="data row9 col1" >... / 2 ts sennep , 3 ss olje , 3 ss hvitvin , 3 ssfmhakket løk , <b>salt</b> og <b>pepper</b></td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Hente ut et kollokasjonsobjekt
#
# Kollokasjoner er ord som forekommer sammen med et søkeuttrykk, ord eller frase eller betingelse

# %%
coll = api.concordance_counts(urns= list(corpus['urn']), words="NEAR(salt pepper, 5)", window=25, limit=1000)

# %%
coll_salt = api.concordance_counts(urns= list(corpus['urn']), words="salt", window=25, limit=1000)

# %% [markdown]
# Resultatet er en dataramme - her ser vi på den sortert

# %%
coll_salt.sort_values(by="freq", ascending=False).head(20)
# Out:
#          freq
# ,       37891
# og      36895
# salt    36893
# .       29361
# i       15762
# med     14802
# pepper  14521
# 1       13090
# til      9385
# 2        9148
# ts       7425
# en       5931
# av       4802
# på       4636
# /        4311
# ss       4307
# g        4165
# litt     4097
# eller    3883
# det      3839

# %% [markdown]
# # Med enkeltord

# %%
coll_word = dh.Collocations(corpus=corpus, words =['salt','Salt'], before=0,after=24)

# %%
coll_word = coll_word.frame

# %%
coll_word.sort_values(by='counts', ascending=False).head(20)
# Out:
#         counts
# .        62678
# ,        45638
# og       37339
# i        26422
# 1        19989
# 2        14404
# pepper   12146
# en        9955
# med       9153
# av        7783
# eller     6842
# (         6786
# -         6761
# til       6378
# det       6234
# er        6151
# den       6127
# på        5937
# )         5848
# /         5785

# %% [markdown]
# # Måle forskjeller
#
# Se også på normalisering i [Python4abm - text in pandas](https://mich123prem.github.io/python4abm/kapittel8.html#analyse-av-kolonner-med-tekst)

# %%
coll_word['counts'].normalize_values()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_3173792/1460071948.py in ?()
# ----> 1 coll_word['counts'].normalize_values()
#
# ~/miniconda3/lib/python3.11/site-packages/pandas/core/generic.py in ?(self, name)
#    6289             and name not in self._accessors
#    6290             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6291         ):
#    6292             return self[name]
# -> 6293         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'normalize_values'
